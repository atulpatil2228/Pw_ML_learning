# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\HP\Downloads\kidney_disease.csv")

# %%
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.drop("id",axis = 1 ,inplace = True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia', 'class']

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df.describe()
# Out:
#               age  blood_pressure  specific_gravity     albumin       sugar  \
# count  391.000000      388.000000        353.000000  354.000000  351.000000
# mean    51.483376       76.469072          1.017408    1.016949    0.450142
# std     17.169714       13.683637          0.005717    1.352679    1.099191
# min      2.000000       50.000000          1.005000    0.000000    0.000000
# 25%     42.000000       70.000000          1.010000    0.000000    0.000000
# 50%     55.000000       80.000000          1.020000    0.000000    0.000000
# 75%     64.500000       80.000000          1.020000    2.000000    0.000000
# max     90.000000      180.000000          1.025000    5.000000    5.000000
#
#        blood_glucose_random  blood_urea  serum_creatinine      sodium  \
# count            356.000000  381.000000        383.000000  313.000000
# mean             148.036517   57.425722          3.072454  137.528754
# std               79.281714   50.503006          5.741126   10.408752
# ...

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume          object
# white_blood_cell_count      object
# red_blood_cell_count        object
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                       object
# dtype: object

# %%
df['packed_cell_volume'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
## due some string int eh column its an object column but say till you
## want to cover into numeric value >> use pd.to_numeric,supreesss the error and convert into nan

# %%
df['packed_cell_volume'] = pd.to_numeric(df['packed_cell_volume'],errors = 'coerce')## coerce meaning supreess or ignore

# %%
df['packed_cell_volume'].dtype
# Out:
# dtype('float64')

# %%
df['packed_cell_volume'].unique()
## all other string character is converte into nana value
# Out:
# array([44., 38., 31., 32., 35., 39., 36., 33., 29., 28., nan, 16., 24.,
#        37., 30., 34., 40., 45., 27., 48., 52., 14., 22., 18., 42., 17.,
#        46., 23., 19., 25., 41., 26., 15., 21., 43., 20., 47.,  9., 49.,
#        50., 53., 51., 54.])

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df['white_blood_cell_count']= pd.to_numeric(df['white_blood_cell_count'],errors = 'coerce')

# %%
df['red_blood_cell_count']= pd.to_numeric(df['red_blood_cell_count'],errors = 'coerce')

# %%
df.dtypes
# Out:
# age                        float64
# blood_pressure             float64
# specific_gravity           float64
# albumin                    float64
# sugar                      float64
# red_blood_cells             object
# pus_cell                    object
# pus_cell_clumps             object
# bacteria                    object
# blood_glucose_random       float64
# blood_urea                 float64
# serum_creatinine           float64
# sodium                     float64
# potassium                  float64
# haemoglobin                float64
# packed_cell_volume         float64
# white_blood_cell_count     float64
# red_blood_cell_count       float64
# hypertension                object
# diabetes_mellitus           object
# coronary_artery_disease     object
# appetite                    object
# peda_edema                  object
# aanemia                     object
# class                       object
# dtype: object

# %%
cat_cols = [ col for col in df.columns if df[col].dtype == 'object']

# %%
num_cols = [ col for col in df.columns if df[col].dtype != 'object']

# %%
num_cols
# Out:
# ['age',
#  'blood_pressure',
#  'specific_gravity',
#  'albumin',
#  'sugar',
#  'blood_glucose_random',
#  'blood_urea',
#  'serum_creatinine',
#  'sodium',
#  'potassium',
#  'haemoglobin',
#  'packed_cell_volume',
#  'white_blood_cell_count',
#  'red_blood_cell_count']

# %%
for col in cat_cols:
    print(f"{col} has {df[col].unique()} values\n")
# Out:
# red_blood_cells has [nan 'normal' 'abnormal'] values
#
# pus_cell has ['normal' 'abnormal' nan] values
#
# pus_cell_clumps has ['notpresent' 'present' nan] values
#
# bacteria has ['notpresent' 'present' nan] values
#
# hypertension has ['yes' 'no' nan] values
#
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
#
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values
#
# appetite has ['good' 'poor' nan] values
#
# peda_edema has ['no' 'yes' nan] values
#
# aanemia has ['no' 'yes' nan] values
#
# class has ['ckd' 'ckd\t' 'notckd'] values

# %%
df['diabetes_mellitus'].replace(to_replace={' yes': 'yes','\tyes' : 'yes','\tno' : 'no'},inplace = True)

# %%
df['diabetes_mellitus'].unique()
# Out:
# array(['yes', 'no', nan], dtype=object)

# %%
df['coronary_artery_disease']= df['coronary_artery_disease'].replace(to_replace='\tno' ,value  = 'no')

# %%
df['coronary_artery_disease'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df['class'] = df['class'].map({'ckd':1, 'notckd':0,'ckd\t':1})
## u could have also first replace and then map wwith 1,0

# %%
df['class'].unique()
# Out:
# array([1, 0])

# %%
## univaraite analysis 
plt.figure(figsize=(10,6))
sns.histplot(df['age'].dropna(),kde = True,bins = 20,color ='skyblue')
plt.title('Dist of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
## insights >> Age is left_Skewwd

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'hypertension',data = df ,palette = 'viridis')
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
## 150 of them has hypertension

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.boxplot(x = 'class',y = 'blood_urea',data = df)
# Out:
# <Axes: xlabel='class', ylabel='blood_urea'>

# %%
### insghts >> people with kidney disease has higher blood_urea with ouliers ,median value is also higher

# %%
sns.violinplot(x = 'class',y ='serum_creatinine',data = df,palette = 'muted')
# Out:
# <Axes: xlabel='class', ylabel='serum_creatinine'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'aanemia',data =df ,palette ='pastel' )
# Out:
# <Axes: xlabel='aanemia', ylabel='count'>

# %%
## majority of the people are not suffering from anemia

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df.appetite.value_counts().plot.pie(autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df.appetite.value_counts().plot.pie(autopct = '%1.1f%%',colors = ['lightcoral','lightgreen'])
## lets make pie chart more beautifull
# Out:
# <Axes: ylabel='count'>

# %%
df.appetite.value_counts().plot.pie(autopct = '%1.1f%%',colors = ['lightcoral','lightgreen'],explode = (0,0.3))
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df.pus_cell_clumps
# Out:
# 0      notpresent
# 1      notpresent
# 2      notpresent
# 3         present
# 4      notpresent
#           ...
# 395    notpresent
# 396    notpresent
# 397    notpresent
# 398    notpresent
# 399    notpresent
# Name: pus_cell_clumps, Length: 400, dtype: object

# %%
sns.countplot(x = 'pus_cell_clumps',data = df)
# Out:
# <Axes: xlabel='pus_cell_clumps', ylabel='count'>

# %%
## Majority of the puss cells are not present

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.histplot(df['white_blood_cell_count'].dropna(),kde = True,bins = 20,color='darkorange')
# Out:
# <Axes: xlabel='white_blood_cell_count', ylabel='Count'>

# %%
## donut chart>> donut chart or ring chart,it s pie chart with whole in the centre
## by secifyong wages propes values
## used to display proportion

# %%
df['diabetes_mellitus'].value_counts().plot.pie(autopct = '%1.1f%%',wedgeprops = dict(width = 0.4))
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'coronary_artery_disease',data = df)
# Out:
# <Axes: xlabel='coronary_artery_disease', ylabel='count'>

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
sns.countplot(x = 'peda_edema',data =df)
# Out:
# <Axes: xlabel='peda_edema', ylabel='count'>

# %%
sns.countplot(x ='bacteria' ,data =df)
# Out:
# <Axes: xlabel='bacteria', ylabel='count'>

# %%
## bivaraite analysis

# %%
sns.scatterplot(x = 'age',y = 'blood_pressure',data = df)
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
## insight >> as age is increasing bp is also increasing

# %%
sns.scatterplot(x = 'age',y = 'blood_pressure',data = df,hue ='class',palette ='coolwarm')
# Out:
# <Axes: xlabel='age', ylabel='blood_pressure'>

# %%
sns.boxplot(x = 'diabetes_mellitus',y='albumin',data =df)
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
sns.violinplot(x = 'diabetes_mellitus',y='albumin',data =df,inner = 'quartile')
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='albumin'>

# %%
## stacked bar chart >> diabetis_mellitus and hypertension
pd.crosstab(df['diabetes_mellitus'],df['hypertension'])
## crosss atb >> sumarizes the data
# Out:
# hypertension        no  yes
# diabetes_mellitus
# no                 220   41
# yes                 31  106

# %%
diabetes_mellitus  =pd.crosstab(df['diabetes_mellitus'],df['hypertension'])
diabetes_mellitus.plot(kind = 'bar',stacked = True)
# Out:
# <Axes: xlabel='diabetes_mellitus'>

# %%
## multivaraite analysis 
## customized pair plot
cols =['age','blood_pressure','blood_glucose_random','serum_creatinine','class']
df[cols]
g = sns.PairGrid(df[cols],hue = 'class',palette = 'coolwarm')
g.map_upper(sns.scatterplot)## upper corner plot
g.map_lower(sns.kdeplot,cmap = 'Blues_d')
g.map_diag(sns.histplot)## diagonal plot
g.add_legend()
plt.title("Pair grid fir selected columns")
plt.show()

# %%
sns.pairplot(df[cols],hue = 'class',palette = 'husl')

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')

# %%
df.corr(numeric_only=True)
# Out:
#                              age  blood_pressure  specific_gravity   albumin  \
# age                     1.000000        0.159480         -0.191096  0.122091
# blood_pressure          0.159480        1.000000         -0.218836  0.160689
# specific_gravity       -0.191096       -0.218836          1.000000 -0.469760
# albumin                 0.122091        0.160689         -0.469760  1.000000
# sugar                   0.220866        0.222576         -0.296234  0.269305
# blood_glucose_random    0.244992        0.160193         -0.374710  0.379464
# blood_urea              0.196985        0.188517         -0.314295  0.453528
# serum_creatinine        0.132531        0.146222         -0.361473  0.399198
# sodium                 -0.100046       -0.116422          0.412190 -0.459896
# potassium               0.058377        0.075151         -0.072787  0.129038
# haemoglobin            -0.192928       -0.306540          0.602582 -0.634632
# ...

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot =True ,cmap = 'coolwarm',linewidth = 0.5)
# Out:
# <Axes: >

# %%
sns.swarmplot(x = 'diabetes_mellitus',y = 'age',hue = 'hypertension',data =df,palette = 'pastel',size = 8)
# Out:
# <Axes: xlabel='diabetes_mellitus', ylabel='age'>

# %%
## swarm plot aloows to see all the overlapping data as well

# %%
fig = px.scatter(df,x = 'age',y = 'blood_pressure',color = 'class')
fig.show()

# %%
fig = px.scatter(df,x = 'age',y = 'blood_pressure',color = 'class',hover_data = ['serum_creatinine','haemoglobin'],title = 'Interactive scatterplot')
fig.show()

# %%
df.columns
# Out:
# Index(['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cells', 'pus_cell', 'pus_cell_clumps', 'bacteria',
#        'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
#        'potassium', 'haemoglobin', 'packed_cell_volume',
#        'white_blood_cell_count', 'red_blood_cell_count', 'hypertension',
#        'diabetes_mellitus', 'coronary_artery_disease', 'appetite',
#        'peda_edema', 'aanemia', 'class'],
#       dtype='object')
