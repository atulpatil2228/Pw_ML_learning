# %% [markdown]
# <a href="https://colab.research.google.com/github/atulpatil2228/Pw_ML_learning/blob/main/4_ensemble_custom_bagging_regressor_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

X, y = make_regression(n_samples=1000, n_features=10, noise=0.1, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
# array([[-2.53028752, -1.97929981,  1.10095963, ...,  0.23924686,
#         -0.91938459,  2.07408267],
#        [-0.33513778,  1.23087451,  1.55416042, ..., -0.87981435,
#         -0.5309709 ,  1.98706111],
#        [-0.8385858 , -0.53121429,  0.53481734, ...,  0.68135951,
#         -0.30780847,  0.40860731],
#        ...,
#        [ 0.03471375, -1.38854255,  0.65497558, ...,  0.15946251,
#          0.51361446, -0.89278752],
#        [-0.7660452 , -1.89967028, -2.25279339, ...,  0.9017287 ,
#         -0.89802723,  0.78414642],
#        [ 1.80051118,  0.05993263,  0.20965942, ..., -1.3088204 ,
#          0.18384954, -3.01951216]])

# %%
y_train
# Out:
# array([ 1.29937428e+02,  2.91143405e+02,  2.31765273e+01,  8.73710227e+01,
#         4.26713781e+01,  4.62649174e+01,  6.31341639e+01, -1.39383877e+01,
#         1.66620220e+01,  7.74378782e+01, -1.26249491e+02,  1.38181951e+02,
#         8.64809979e+01, -3.06160749e+01, -6.09786531e+01, -9.65370607e+01,
#         1.08928070e+02,  5.35961730e+01,  4.77213182e+01, -6.94385430e+01,
#         1.57457830e+02, -2.11848821e+02,  2.10305098e+00, -3.34201965e+01,
#        -2.34098014e+02,  9.26828052e+01,  3.17126573e+01, -8.17877699e+01,
#        -2.55767125e+01, -1.34061177e+02,  2.64804191e+01, -4.13931823e+01,
#        -1.11575069e+02, -5.31825197e+00, -3.91303803e+01,  4.61587838e+01,
#         1.09752879e+02,  1.18186374e+02, -1.28566733e+02, -5.44888341e+00,
#        -4.28411226e+01,  2.30708902e+01, -9.45222784e+01,  1.06770849e+02,
#         2.59109294e+02, -2.08215270e+01, -2.22570613e+02,  1.68678529e+02,
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lr = LinearRegression()
dtr = DecisionTreeRegressor()
svr = SVR(kernel = 'linear')

# %%
## To create ensembles
from sklearn.ensemble import VotingRegressor

# %%
ensemble_regressor = VotingRegressor(estimators=[('mlr',lr),('dtr',dtr),('svr',svr)])

# %%
ensemble_regressor
# Out:
# VotingRegressor(estimators=[('mlr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('svr', SVR(kernel='linear'))])

# %%
ensemble_regressor.fit(X_train,y_train)
# Out:
# VotingRegressor(estimators=[('mlr', LinearRegression()),
#                             ('dtr', DecisionTreeRegressor()),
#                             ('svr', SVR(kernel='linear'))])

# %%
y_pred = ensemble_regressor.predict(X_test)

# %%
y_pred
# Out:
# array([ 204.17151487,   13.24925606, -189.12036416,   94.52711716,
#        -204.70088094,  -96.21960286,   90.62339474,  -54.4567635 ,
#          12.72986794,  172.76912235,  260.48406947,  219.95471429,
#           8.2343784 ,   12.64928682,  -92.34215185,  -16.48076548,
#          19.98488611,  -60.46692889,  -23.51545498,   48.36786505,
#         -51.84420906,  -59.28520438,   22.50593064, -164.74934807,
#         104.14982406,   55.62772478, -136.00797228,   31.03204276,
#         156.0776996 ,  -64.6560655 ,  -39.24294945, -125.06000696,
#          39.97185693, -170.16880216,  -16.8060536 ,  103.01647057,
#          90.22191157,  -83.3596373 ,   13.31396403,  122.18356362,
#          60.70907428,    1.76366623,   64.82237389, -204.85490261,
#         -40.79697003,  164.81270538, -242.7769886 ,   95.56241555,
#          29.53497237,   96.06841592,  125.40469099,   -2.45944441,
#         -54.09498338,  118.61794558,  -54.82223067,   80.37550235,
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9550238732110667
