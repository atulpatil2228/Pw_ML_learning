# %% [markdown]
# <a href="https://colab.research.google.com/github/atulpatil2228/Pw_ML_learning/blob/main/3_Data_Interpolation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## data interpolation >> it is a process of estimating values of unknow values from the known values

## linear interpolation
## cubic
## polynominal

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 3, 5, 7, 9])

plt.scatter(x, y)

# %%
## linear interpolatio >>linear in nature
x_new = np.linspace(1,5,10)## create new x values
y_interp = np.interp(x_new,x,y)

# %%
y_interp
# Out:
# array([1.        , 1.88888889, 2.77777778, 3.66666667, 4.55555556,
#        5.44444444, 6.33333333, 7.22222222, 8.11111111, 9.        ])

# %%
plt.scatter(x_new,y_interp)

# %%
#cubic interpolation
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 8, 27, 64, 125])

plt.scatter(x, y)

# %%
from scipy.interpolate import interp1d
f = interp1d(x,y,kind = 'cubic')

# %%
f

# %%
np.linspace(1,5,10)
y_interp = f(x_new)

# %%
y_interp
# Out:
# array([  1.        ,   3.01371742,   6.739369  ,  12.7037037 ,
#         21.43347051,  33.45541838,  49.2962963 ,  69.48285322,
#         94.54183813, 125.        ])

# %%
plt.scatter(x_new,y_interp)

# %%
## polynominal interpolation
#polynomial interpolation
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 4, 9, 1, 25])

#interpolate using polynomial interpolation
p = np.polyfit(x, y, 2)

# %%
x_new = np.linspace(x,y,2)
y_interp = np.polyval(p,x_new)
plt.scatter(x,y)

# %%
plt.scatter(x_new,y_interp)

# %%
#use case >> missing data, generation of new datapoint
